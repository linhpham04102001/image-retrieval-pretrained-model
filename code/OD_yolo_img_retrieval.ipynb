# %%
# !pip install --upgrade gdown   # update gdown
# !gdown 14pf06S_6lalxmNW_bIgClXvki7Oqfnwi  # Download database images
# !gdown 1BhbQlsHiztZrYbq9ApcuLpTaFYn8a5cq # Download detection model
# !gdown 1FiWVKqFM0E0EnlmrjwS1ldJoufjd0Ziv # Download features model

# !unzip /content/detection.zip

# !mv  /content/detection  /content/image_retrieval     
# !mv  /content/80_features_db.npz  /content/image_retrieval/db 
# !mkdir /content/image_retrieval/test_case
# !mkdir /content/image_retrieval/test_case/inp
# !mkdir /content/image_retrieval/test_case/out
# !wget https://www.quickanddirtytips.com/wp-content/uploads/2022/05/ezgif.com-gif-maker-3.jpg -P /content/image_retrieval/test_case/inp
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Cat03.jpg/800px-Cat03.jpg -P /content/image_retrieval/test_case/inp

# !rm -rf /content/imgs_db.zip
# !rm -rf /content/detection.zip

# %%
# %cd /content/image_retrieval

import sys 
sys.path.insert(0, "/content/image_retrieval/detection/yolov5")
# sys.path.insert(0, "/content/image_retrieval/detection/yolov7")

from detection.detector import YOLO
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# /content/image_retrieval

# %%
class SearchEngine:
    def __init__(self, model, dir_images, p_src_features):
        if model == "yolov5":
            self.model = YOLO("/content/image_retrieval/detection/weights/yolov5s.pt")

        if p_src_features is None or not os.path.exists(p_src_features):
            self.db_extract_features(dir_images, p_src_features)
        db = np.load(p_src_features)
        self.path_imgs = db["p_imgs"]
        self.src_features = db["features"]   
    
    def load_img(self, img):
        if isinstance(img, str):
            img = cv2.imread(img)
        return img
        
    def preprocess(self, img):
        img = self.load_img(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        return img

    # Extract feature from image
    def extractor(self, img):
        img = self.preprocess(img)
        boxes, scores, clss = self.model.predict(img)
        feature = np.zeros((80, ), dtype=np.int32)
        if len(clss) <= 0:
            return feature[None, :]
        clss_unique = np.unique(clss.astype(int))
        feature[clss_unique] = 1
        return feature[None, :]
    
    def search(self, query_img, display=True, top=30):
        dest_feature = self.extractor(query_img)
        scores = (dest_feature @ self.src_features.T)[0]
        idxs_max = np.argsort(scores)[::-1][:top]
        if display:
            self.display(self.path_imgs[idxs_max])

        return list(zip(scores[idxs_max], self.path_imgs[idxs_max]))

    # Display result
    def display(self, paths, columns = 5, rows = 6):
        fig = plt.figure(figsize=(15, 15))
        for i, path in enumerate(paths):
            fig.add_subplot(rows, columns, i + 1)
            plt.imshow(plt.imread(path))
            plt.axis("off")
        plt.show()

    # Extract database images to features
    def db_extract_features(self, dir_images, p_src_features):
        path_imgs = []
        features = []
        for dir_cls in tqdm(os.listdir(dir_images)):
            for idx, name_img in enumerate(os.listdir(f"{dir_images}/{dir_cls}")):
                try:
                    p_img = f"{dir_images}/{dir_cls}/{name_img}"
                    feature = self.extractor(p_img)
                    features.extend(feature)
                    path_imgs.append(p_img)
                except:
                    print("error:", p_img)

        path_imgs = np.array(path_imgs)
        features = np.array(features)

        np.savez(p_src_features, p_imgs=path_imgs, features=features)

# %%
dir_images="/content/image_retrieval/db/imgs_db"
p_src_features="/content/image_retrieval/db/80_features_db.npz"
model="yolov5"
search_engine = SearchEngine(model=model, dir_images=dir_images, p_src_features=p_src_features)

# %%
# %matplotlib inline
p_query = "/content/image_retrieval/test_case/inp/800px-Cat03.jpg"
search_engine.search(p_query)
# Out:
# [(1, '/content/image_retrieval/imgs_db/animal_Cat/0.7658480391257148.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.6179361803081467.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.43528955268133396.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.9835193149633791.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.8169363140814755.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.04859980700044497.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.06829488435540676.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_fox/0.7786599859361392.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.6429256476968039.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.1709569939867227.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.701249155898456.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_fox/0.7907239542022763.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.7227999495269972.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.5931333826355629.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.8846288823659793.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.9817143934593948.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.46546136084434864.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.20186876041321022.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_fox/0.97528859679712.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.828460722164708.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.31689910435925983.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_fox/0.18240263214382013.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.06626281594696692.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.34206740202296426.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.7173429849132997.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.05462993087915158.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.1273383347185194.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.14010652795161416.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_fox/0.5751916173831152.jpg'),
#  (1, '/content/image_retrieval/imgs_db/animal_Cat/0.6757665038496523.jpg')]

# %%
# %matplotlib inline
p_query = "/content/image_retrieval/test_case/inp/ezgif.com-gif-maker-3.jpg"
search_engine.search(p_query)
# Out:
# [(2, '/content/image_retrieval/imgs_db/animal_Dog/0.04506701790979295.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.9991871062328662.jpg'),
#  (2,
#   '/content/image_retrieval/imgs_db/scenery_lighthouse/0.415802123451781.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.5783341617823247.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Alpaca/0.15329815250723478.jpg'),
#  (2,
#   '/content/image_retrieval/imgs_db/scenery_flowergarden/0.23897738573296146.jpg'),
#  (2, '/content/image_retrieval/imgs_db/plant_Grass/0.8537603514046044.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.0037493321757283704.jpg'),
#  (2,
#   '/content/image_retrieval/imgs_db/scenery_lighthouse/0.16340142293127635.jpg'),
#  (2,
#   '/content/image_retrieval/imgs_db/scenery_lighthouse/0.9064458667203816.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.16263688208814298.jpg'),
#  (2, '/content/image_retrieval/imgs_db/plant_Grass/0.6331582640917811.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_pig/0.7271144028956317.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.41498693967543754.jpg'),
#  (2,
#   '/content/image_retrieval/imgs_db/scenery_lighthouse/0.6054121185343084.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.9585002768237942.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Cat/0.608628435366838.jpg'),
#  (2,
#   '/content/image_retrieval/imgs_db/scenery_lighthouse/0.8181807518564749.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_fox/0.870055160373838.jpg'),
#  (2, '/content/image_retrieval/imgs_db/plant_Grass/0.1916535000479822.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Alpaca/0.33454158992325467.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Cock/0.7228431143866377.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Cat/0.130657460613272.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_pig/0.06750316242474563.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.37834386177304746.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.9842133712683502.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.33677411550930436.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Alpaca/0.8919079988761133.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.6872761282451025.jpg'),
#  (2, '/content/image_retrieval/imgs_db/animal_Dog/0.4139944176227568.jpg')]
